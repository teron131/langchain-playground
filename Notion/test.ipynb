# %%
from typing import List

from formatters import BaseFormatter, LatexFormatter, Rephraser
from notion_api import NotionAPI


def process_with_formatters(blocks: List[dict], formatters: List[BaseFormatter]) -> None:
    """
    Process blocks through a sequence of formatters.

    Args:
        blocks (List[dict]): Notion blocks to process
        formatters (List[BaseFormatter]): List of formatters to apply
    """
    for formatter in formatters:
        formatter.process_blocks(blocks)


notion_api = NotionAPI()
blocks = notion_api.read_blocks()

blocks
# Out:
# [{'object': 'block',
#   'id': '145bb2c6-d133-804d-a8e0-d751fbfdcb39',
#   'parent': {'type': 'page_id',
#    'page_id': '145bb2c6-d133-8027-830c-d4a587baf1fc'},
#   'created_time': '2024-11-21T07:15:00.000Z',
#   'last_edited_time': '2024-11-26T06:01:00.000Z',
#   'created_by': {'object': 'user',
#    'id': '3c876d9c-6506-491d-ae3f-65fa9933efaa'},
#   'last_edited_by': {'object': 'user',
#    'id': '3c876d9c-6506-491d-ae3f-65fa9933efaa'},
#   'has_children': False,
#   'archived': False,
#   'in_trash': False,
#   'type': 'paragraph',
#   'paragraph': {'rich_text': [{'type': 'text',
#      'text': {'content': "Quadratic programming (QP) is a type of mathematical optimization problem that involves minimizing (or maximizing) a quadratic objective function subject to linear constraints. Quadratic programming is a special case of convex optimization when the quadratic objective function is convex, meaning the matrix that defines the quadratic term is positive semidefinite. Here's a breakdown of the concepts involved:",
#       'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': "Quadratic programming (QP) is a type of mathematical optimization problem that involves minimizing (or maximizing) a quadratic objective function subject to linear constraints. Quadratic programming is a special case of convex optimization when the quadratic objective function is convex, meaning the matrix that defines the quadratic term is positive semidefinite. Here's a breakdown of the concepts involved:",
#      'href': None}],
#    'color': 'default'}},
#  {'object': 'block',
#   'id': '145bb2c6-d133-8048-93a5-d170870665ea',
#   'parent': {'type': 'page_id',
#    'page_id': '145bb2c6-d133-8027-830c-d4a587baf1fc'},
#   'created_time': '2024-11-21T07:15:00.000Z',
#   'last_edited_time': '2024-11-26T06:01:00.000Z',
#   'created_by': {'object': 'user',
#    'id': '3c876d9c-6506-491d-ae3f-65fa9933efaa'},
#   'last_edited_by': {'object': 'user',
#    'id': '3c876d9c-6506-491d-ae3f-65fa9933efaa'},
#   'has_children': False,
#   'archived': False,
#   'in_trash': False,
#   'type': 'heading_3',
#   'heading_3': {'rich_text': [{'type': 'text',
#      'text': {'content': 'Objective Function', 'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': 'Objective Function',
#      'href': None}],
#    'is_toggleable': False,
#    'color': 'default'}},
#  {'object': 'block',
#   'id': '145bb2c6-d133-80b1-8a87-f1c6ce5432cf',
#   'parent': {'type': 'page_id',
#    'page_id': '145bb2c6-d133-8027-830c-d4a587baf1fc'},
#   'created_time': '2024-11-21T07:15:00.000Z',
#   'last_edited_time': '2024-11-26T06:01:00.000Z',
#   'created_by': {'object': 'user',
#    'id': '3c876d9c-6506-491d-ae3f-65fa9933efaa'},
#   'last_edited_by': {'object': 'user',
#    'id': '3c876d9c-6506-491d-ae3f-65fa9933efaa'},
#   'has_children': False,
#   'archived': False,
#   'in_trash': False,
#   'type': 'paragraph',
#   'paragraph': {'rich_text': [{'type': 'text',
#      'text': {'content': 'In quadratic programming, the objective function is typically in the form:',
#       'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': 'In quadratic programming, the objective function is typically in the form:',
#      'href': None}],
#    'color': 'default'}},
#  {'object': 'block',
#   'id': '145bb2c6-d133-8041-9fe2-e93b63fe6c78',
#   'parent': {'type': 'page_id',
#    'page_id': '145bb2c6-d133-8027-830c-d4a587baf1fc'},
#   'created_time': '2024-11-21T07:15:00.000Z',
#   'last_edited_time': '2024-11-26T06:01:00.000Z',
#   'created_by': {'object': 'user',
#    'id': '3c876d9c-6506-491d-ae3f-65fa9933efaa'},
#   'last_edited_by': {'object': 'user',
#    'id': '3c876d9c-6506-491d-ae3f-65fa9933efaa'},
#   'has_children': False,
#   'archived': False,
#   'in_trash': False,
#   'type': 'paragraph',
#   'paragraph': {'rich_text': [{'type': 'text',
#      'text': {'content': '\\[ f(x) = \\frac{1}{2} x^T Q x + c^T x \\]',
#       'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': '\\[ f(x) = \\frac{1}{2} x^T Q x + c^T x \\]',
#      'href': None}],
#    'color': 'default'}},
#  {'object': 'block',
#   'id': '145bb2c6-d133-8084-be4b-d20e2337dd91',
#   'parent': {'type': 'page_id',
#    'page_id': '145bb2c6-d133-8027-830c-d4a587baf1fc'},
#   'created_time': '2024-11-21T07:15:00.000Z',
#   'last_edited_time': '2024-11-26T06:01:00.000Z',
#   'created_by': {'object': 'user',
#    'id': '3c876d9c-6506-491d-ae3f-65fa9933efaa'},
#   'last_edited_by': {'object': 'user',
#    'id': '3c876d9c-6506-491d-ae3f-65fa9933efaa'},
#   'has_children': False,
#   'archived': False,
#   'in_trash': False,
#   'type': 'bulleted_list_item',
#   'bulleted_list_item': {'rich_text': [{'type': 'text',
#      'text': {'content': '\\( x \\) is the vector of variables to be optimized.',
#       'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': '\\( x \\) is the vector of variables to be optimized.',
#      'href': None}],
#    'color': 'default'}},
#  {'object': 'block',
#   'id': '145bb2c6-d133-807d-8508-f562ec6975bf',
#   'parent': {'type': 'page_id',
#    'page_id': '145bb2c6-d133-8027-830c-d4a587baf1fc'},
#   'created_time': '2024-11-21T07:15:00.000Z',
#   'last_edited_time': '2024-11-26T06:01:00.000Z',
#   'created_by': {'object': 'user',
#    'id': '3c876d9c-6506-491d-ae3f-65fa9933efaa'},
#   'last_edited_by': {'object': 'user',
#    'id': '3c876d9c-6506-491d-ae3f-65fa9933efaa'},
#   'has_children': False,
#   'archived': False,
#   'in_trash': False,
#   'type': 'bulleted_list_item',
#   'bulleted_list_item': {'rich_text': [{'type': 'text',
#      'text': {'content': '\\( Q \\) is a symmetric matrix that defines the quadratic part of the objective function.',
#       'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': '\\( Q \\) is a symmetric matrix that defines the quadratic part of the objective function.',
#      'href': None}],
#    'color': 'default'}},
#  {'object': 'block',
#   'id': '145bb2c6-d133-80b0-86d1-f98d23ebd7e8',
#   'parent': {'type': 'page_id',
#    'page_id': '145bb2c6-d133-8027-830c-d4a587baf1fc'},
#   'created_time': '2024-11-21T07:15:00.000Z',
#   'last_edited_time': '2024-11-26T06:01:00.000Z',
#   'created_by': {'object': 'user',
#    'id': '3c876d9c-6506-491d-ae3f-65fa9933efaa'},
#   'last_edited_by': {'object': 'user',
#    'id': '3c876d9c-6506-491d-ae3f-65fa9933efaa'},
#   'has_children': False,
#   'archived': False,
#   'in_trash': False,
#   'type': 'bulleted_list_item',
#   'bulleted_list_item': {'rich_text': [{'type': 'text',
#      'text': {'content': '\\( c \\) is a vector that defines the linear part of the objective function.',
#       'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': '\\( c \\) is a vector that defines the linear part of the objective function.',
#      'href': None}],
#    'color': 'default'}},
#  {'object': 'block',
#   'id': '145bb2c6-d133-8080-bdcf-d384e9d2c597',
#   'parent': {'type': 'page_id',
#    'page_id': '145bb2c6-d133-8027-830c-d4a587baf1fc'},
#   'created_time': '2024-11-21T07:15:00.000Z',
#   'last_edited_time': '2024-11-26T06:01:00.000Z',
#   'created_by': {'object': 'user',
#    'id': '3c876d9c-6506-491d-ae3f-65fa9933efaa'},
#   'last_edited_by': {'object': 'user',
#    'id': '3c876d9c-6506-491d-ae3f-65fa9933efaa'},
#   'has_children': False,
#   'archived': False,
#   'in_trash': False,
#   'type': 'paragraph',
#   'paragraph': {'rich_text': [{'type': 'text',
#      'text': {'content': 'The problem is convex if \\( Q \\) is a positive semidefinite matrix, meaning all its eigenvalues are non-negative. In such cases, the objective function exhibits a bowl shape, and any local minimum is also a global minimum.',
#       'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': 'The problem is convex if \\( Q \\) is a positive semidefinite matrix, meaning all its eigenvalues are non-negative. In such cases, the objective function exhibits a bowl shape, and any local minimum is also a global minimum.',
#      'href': None}],
#    'color': 'default'}},
#  {'object': 'block',
#   'id': '145bb2c6-d133-807c-97de-ec814308b665',
#   'parent': {'type': 'page_id',
#    'page_id': '145bb2c6-d133-8027-830c-d4a587baf1fc'},
#   'created_time': '2024-11-21T07:15:00.000Z',
#   'last_edited_time': '2024-11-26T06:01:00.000Z',
#   'created_by': {'object': 'user',
#    'id': '3c876d9c-6506-491d-ae3f-65fa9933efaa'},
#   'last_edited_by': {'object': 'user',
#    'id': '3c876d9c-6506-491d-ae3f-65fa9933efaa'},
#   'has_children': False,
#   'archived': False,
#   'in_trash': False,
#   'type': 'heading_3',
#   'heading_3': {'rich_text': [{'type': 'text',
#      'text': {'content': 'Constraints', 'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': 'Constraints',
#      'href': None}],
#    'is_toggleable': False,
#    'color': 'default'}},
#  {'object': 'block',
#   'id': '145bb2c6-d133-806f-a55b-d3cf79e2f70e',
#   'parent': {'type': 'page_id',
#    'page_id': '145bb2c6-d133-8027-830c-d4a587baf1fc'},
#   'created_time': '2024-11-21T07:15:00.000Z',
#   'last_edited_time': '2024-11-26T06:01:00.000Z',
#   'created_by': {'object': 'user',
#    'id': '3c876d9c-6506-491d-ae3f-65fa9933efaa'},
#   'last_edited_by': {'object': 'user',
#    'id': '3c876d9c-6506-491d-ae3f-65fa9933efaa'},
#   'has_children': False,
#   'archived': False,
#   'in_trash': False,
#   'type': 'paragraph',
#   'paragraph': {'rich_text': [{'type': 'text',
#      'text': {'content': 'The constraints in quadratic programming are typically linear and can be expressed as:',
#       'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': 'The constraints in quadratic programming are typically linear and can be expressed as:',
#      'href': None}],
#    'color': 'default'}},
#  {'object': 'block',
#   'id': '145bb2c6-d133-8066-a86c-dc497f86e365',
#   'parent': {'type': 'page_id',
#    'page_id': '145bb2c6-d133-8027-830c-d4a587baf1fc'},
#   'created_time': '2024-11-21T07:15:00.000Z',
#   'last_edited_time': '2024-11-26T06:01:00.000Z',
#   'created_by': {'object': 'user',
#    'id': '3c876d9c-6506-491d-ae3f-65fa9933efaa'},
#   'last_edited_by': {'object': 'user',
#    'id': '3c876d9c-6506-491d-ae3f-65fa9933efaa'},
#   'has_children': False,
#   'archived': False,
#   'in_trash': False,
#   'type': 'bulleted_list_item',
#   'bulleted_list_item': {'rich_text': [{'type': 'text',
#      'text': {'content': 'Equality constraints', 'link': None},
#      'annotations': {'bold': True,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': 'Equality constraints',
#      'href': None},
#     {'type': 'text',
#      'text': {'content': ': \\( A_{eq} x = b_{eq} \\)', 'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': ': \\( A_{eq} x = b_{eq} \\)',
#      'href': None}],
#    'color': 'default'}},
#  {'object': 'block',
#   'id': '145bb2c6-d133-808f-8d78-cae3e35ae0bb',
#   'parent': {'type': 'page_id',
#    'page_id': '145bb2c6-d133-8027-830c-d4a587baf1fc'},
#   'created_time': '2024-11-21T07:15:00.000Z',
#   'last_edited_time': '2024-11-26T06:01:00.000Z',
#   'created_by': {'object': 'user',
#    'id': '3c876d9c-6506-491d-ae3f-65fa9933efaa'},
#   'last_edited_by': {'object': 'user',
#    'id': '3c876d9c-6506-491d-ae3f-65fa9933efaa'},
#   'has_children': False,
#   'archived': False,
#   'in_trash': False,
#   'type': 'bulleted_list_item',
#   'bulleted_list_item': {'rich_text': [{'type': 'text',
#      'text': {'content': 'Inequality constraints', 'link': None},
#      'annotations': {'bold': True,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': 'Inequality constraints',
#      'href': None},
#     {'type': 'text',
#      'text': {'content': ': \\( A_{ineq} x \\leq b_{ineq} \\)', 'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': ': \\( A_{ineq} x \\leq b_{ineq} \\)',
#      'href': None}],
#    'color': 'default'}},
#  {'object': 'block',
#   'id': '145bb2c6-d133-8071-9fc3-d9bb209806e6',
#   'parent': {'type': 'page_id',
#    'page_id': '145bb2c6-d133-8027-830c-d4a587baf1fc'},
#   'created_time': '2024-11-21T07:15:00.000Z',
#   'last_edited_time': '2024-11-26T06:01:00.000Z',
#   'created_by': {'object': 'user',
#    'id': '3c876d9c-6506-491d-ae3f-65fa9933efaa'},
#   'last_edited_by': {'object': 'user',
#    'id': '3c876d9c-6506-491d-ae3f-65fa9933efaa'},
#   'has_children': False,
#   'archived': False,
#   'in_trash': False,
#   'type': 'bulleted_list_item',
#   'bulleted_list_item': {'rich_text': [{'type': 'text',
#      'text': {'content': '\\( A_{eq} \\) and \\( A_{ineq} \\) are matrices defining the linear constraints.',
#       'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': '\\( A_{eq} \\) and \\( A_{ineq} \\) are matrices defining the linear constraints.',
#      'href': None}],
#    'color': 'default'}},
#  {'object': 'block',
#   'id': '145bb2c6-d133-80e9-b789-f45ea6a586f8',
#   'parent': {'type': 'page_id',
#    'page_id': '145bb2c6-d133-8027-830c-d4a587baf1fc'},
#   'created_time': '2024-11-21T07:15:00.000Z',
#   'last_edited_time': '2024-11-26T06:01:00.000Z',
#   'created_by': {'object': 'user',
#    'id': '3c876d9c-6506-491d-ae3f-65fa9933efaa'},
#   'last_edited_by': {'object': 'user',
#    'id': '3c876d9c-6506-491d-ae3f-65fa9933efaa'},
#   'has_children': False,
#   'archived': False,
#   'in_trash': False,
#   'type': 'bulleted_list_item',
#   'bulleted_list_item': {'rich_text': [{'type': 'text',
#      'text': {'content': '\\( b_{eq} \\) and \\( b_{ineq} \\) are vectors representing the bounds for the constraints.',
#       'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': '\\( b_{eq} \\) and \\( b_{ineq} \\) are vectors representing the bounds for the constraints.',
#      'href': None}],
#    'color': 'default'}},
#  {'object': 'block',
#   'id': '145bb2c6-d133-8091-a3c0-ee32d0843449',
#   'parent': {'type': 'page_id',
#    'page_id': '145bb2c6-d133-8027-830c-d4a587baf1fc'},
#   'created_time': '2024-11-21T07:15:00.000Z',
#   'last_edited_time': '2024-11-26T06:01:00.000Z',
#   'created_by': {'object': 'user',
#    'id': '3c876d9c-6506-491d-ae3f-65fa9933efaa'},
#   'last_edited_by': {'object': 'user',
#    'id': '3c876d9c-6506-491d-ae3f-65fa9933efaa'},
#   'has_children': False,
#   'archived': False,
#   'in_trash': False,
#   'type': 'heading_3',
#   'heading_3': {'rich_text': [{'type': 'text',
#      'text': {'content': 'Solving Quadratic Programs', 'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': 'Solving Quadratic Programs',
#      'href': None}],
#    'is_toggleable': False,
#    'color': 'default'}},
#  {'object': 'block',
#   'id': '145bb2c6-d133-80dc-b7fa-ff0cd3985001',
#   'parent': {'type': 'page_id',
#    'page_id': '145bb2c6-d133-8027-830c-d4a587baf1fc'},
#   'created_time': '2024-11-21T07:15:00.000Z',
#   'last_edited_time': '2024-11-26T06:01:00.000Z',
#   'created_by': {'object': 'user',
#    'id': '3c876d9c-6506-491d-ae3f-65fa9933efaa'},
#   'last_edited_by': {'object': 'user',
#    'id': '3c876d9c-6506-491d-ae3f-65fa9933efaa'},
#   'has_children': False,
#   'archived': False,
#   'in_trash': False,
#   'type': 'paragraph',
#   'paragraph': {'rich_text': [{'type': 'text',
#      'text': {'content': 'Solving a quadratic programming problem involves finding the optimal \\( x \\) that minimizes the objective function while satisfying the constraints. Various algorithms can be used to solve QP problems, including:',
#       'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': 'Solving a quadratic programming problem involves finding the optimal \\( x \\) that minimizes the objective function while satisfying the constraints. Various algorithms can be used to solve QP problems, including:',
#      'href': None}],
#    'color': 'default'}},
#  {'object': 'block',
#   'id': '145bb2c6-d133-80b1-8dc8-c3631622211b',
#   'parent': {'type': 'page_id',
#    'page_id': '145bb2c6-d133-8027-830c-d4a587baf1fc'},
#   'created_time': '2024-11-21T07:15:00.000Z',
#   'last_edited_time': '2024-11-26T06:01:00.000Z',
#   'created_by': {'object': 'user',
#    'id': '3c876d9c-6506-491d-ae3f-65fa9933efaa'},
#   'last_edited_by': {'object': 'user',
#    'id': '3c876d9c-6506-491d-ae3f-65fa9933efaa'},
#   'has_children': False,
#   'archived': False,
#   'in_trash': False,
#   'type': 'bulleted_list_item',
#   'bulleted_list_item': {'rich_text': [{'type': 'text',
#      'text': {'content': 'Interior-point methods', 'link': None},
#      'annotations': {'bold': True,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': 'Interior-point methods',
#      'href': None},
#     {'type': 'text',
#      'text': {'content': ': Efficient for large-scale problems.',
#       'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': ': Efficient for large-scale problems.',
#      'href': None}],
#    'color': 'default'}},
#  {'object': 'block',
#   'id': '145bb2c6-d133-80f0-85d4-e2bebe68f83c',
#   'parent': {'type': 'page_id',
#    'page_id': '145bb2c6-d133-8027-830c-d4a587baf1fc'},
#   'created_time': '2024-11-21T07:15:00.000Z',
#   'last_edited_time': '2024-11-26T06:01:00.000Z',
#   'created_by': {'object': 'user',
#    'id': '3c876d9c-6506-491d-ae3f-65fa9933efaa'},
#   'last_edited_by': {'object': 'user',
#    'id': '3c876d9c-6506-491d-ae3f-65fa9933efaa'},
#   'has_children': False,
#   'archived': False,
#   'in_trash': False,
#   'type': 'bulleted_list_item',
#   'bulleted_list_item': {'rich_text': [{'type': 'text',
#      'text': {'content': 'Active-set methods', 'link': None},
#      'annotations': {'bold': True,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': 'Active-set methods',
#      'href': None},
#     {'type': 'text',
#      'text': {'content': ': Suitable for problems with a small number of constraints.',
#       'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': ': Suitable for problems with a small number of constraints.',
#      'href': None}],
#    'color': 'default'}},
#  {'object': 'block',
#   'id': '145bb2c6-d133-8008-a35e-c9094814cb87',
#   'parent': {'type': 'page_id',
#    'page_id': '145bb2c6-d133-8027-830c-d4a587baf1fc'},
#   'created_time': '2024-11-21T07:15:00.000Z',
#   'last_edited_time': '2024-11-26T06:01:00.000Z',
#   'created_by': {'object': 'user',
#    'id': '3c876d9c-6506-491d-ae3f-65fa9933efaa'},
#   'last_edited_by': {'object': 'user',
#    'id': '3c876d9c-6506-491d-ae3f-65fa9933efaa'},
#   'has_children': False,
#   'archived': False,
#   'in_trash': False,
#   'type': 'bulleted_list_item',
#   'bulleted_list_item': {'rich_text': [{'type': 'text',
#      'text': {'content': 'Gradient projection methods', 'link': None},
#      'annotations': {'bold': True,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': 'Gradient projection methods',
#      'href': None},
#     {'type': 'text',
#      'text': {'content': ': Often used for problems with simple bound constraints.',
#       'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': ': Often used for problems with simple bound constraints.',
#      'href': None}],
#    'color': 'default'}},
#  {'object': 'block',
#   'id': '145bb2c6-d133-806a-885d-d15777d855a6',
#   'parent': {'type': 'page_id',
#    'page_id': '145bb2c6-d133-8027-830c-d4a587baf1fc'},
#   'created_time': '2024-11-21T07:15:00.000Z',
#   'last_edited_time': '2024-11-26T06:01:00.000Z',
#   'created_by': {'object': 'user',
#    'id': '3c876d9c-6506-491d-ae3f-65fa9933efaa'},
#   'last_edited_by': {'object': 'user',
#    'id': '3c876d9c-6506-491d-ae3f-65fa9933efaa'},
#   'has_children': False,
#   'archived': False,
#   'in_trash': False,
#   'type': 'heading_3',
#   'heading_3': {'rich_text': [{'type': 'text',
#      'text': {'content': 'Applications', 'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': 'Applications',
#      'href': None}],
#    'is_toggleable': False,
#    'color': 'default'}},
#  {'object': 'block',
#   'id': '145bb2c6-d133-806c-9ac2-fc9a3ec7d436',
#   'parent': {'type': 'page_id',
#    'page_id': '145bb2c6-d133-8027-830c-d4a587baf1fc'},
#   'created_time': '2024-11-21T07:15:00.000Z',
#   'last_edited_time': '2024-11-26T06:01:00.000Z',
#   'created_by': {'object': 'user',
#    'id': '3c876d9c-6506-491d-ae3f-65fa9933efaa'},
#   'last_edited_by': {'object': 'user',
#    'id': '3c876d9c-6506-491d-ae3f-65fa9933efaa'},
#   'has_children': False,
#   'archived': False,
#   'in_trash': False,
#   'type': 'paragraph',
#   'paragraph': {'rich_text': [{'type': 'text',
#      'text': {'content': 'Quadratic programming is widely used in various fields such as finance (portfolio optimization), engineering (control systems), and machine learning (support vector machines).',
#       'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': 'Quadratic programming is widely used in various fields such as finance (portfolio optimization), engineering (control systems), and machine learning (support vector machines).',
#      'href': None}],
#    'color': 'default'}},
#  {'object': 'block',
#   'id': '145bb2c6-d133-8077-859a-e8ae7b94120e',
#   'parent': {'type': 'page_id',
#    'page_id': '145bb2c6-d133-8027-830c-d4a587baf1fc'},
#   'created_time': '2024-11-21T07:15:00.000Z',
#   'last_edited_time': '2024-11-26T06:01:00.000Z',
#   'created_by': {'object': 'user',
#    'id': '3c876d9c-6506-491d-ae3f-65fa9933efaa'},
#   'last_edited_by': {'object': 'user',
#    'id': '3c876d9c-6506-491d-ae3f-65fa9933efaa'},
#   'has_children': False,
#   'archived': False,
#   'in_trash': False,
#   'type': 'paragraph',
#   'paragraph': {'rich_text': [{'type': 'text',
#      'text': {'content': 'In summary, quadratic programming in convex optimization involves minimizing a convex quadratic function subject to linear constraints. The convexity of the problem ensures that any local minimum is also a global minimum, making it a powerful tool in optimization.',
#       'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': 'In summary, quadratic programming in convex optimization involves minimizing a convex quadratic function subject to linear constraints. The convexity of the problem ensures that any local minimum is also a global minimum, making it a powerful tool in optimization.',
#      'href': None}],
#    'color': 'default'}},
#  {'object': 'block',
#   'id': '145bb2c6-d133-8050-8eaa-c04f35b8186d',
#   'parent': {'type': 'page_id',
#    'page_id': '145bb2c6-d133-8027-830c-d4a587baf1fc'},
#   'created_time': '2024-11-21T07:15:00.000Z',
#   'last_edited_time': '2024-11-26T05:56:00.000Z',
#   'created_by': {'object': 'user',
#    'id': '3c876d9c-6506-491d-ae3f-65fa9933efaa'},
#   'last_edited_by': {'object': 'user',
#    'id': 'fc782041-63ee-4257-860a-f10c2b0325b7'},
#   'has_children': False,
#   'archived': False,
#   'in_trash': False,
#   'type': 'paragraph',
#   'paragraph': {'rich_text': [], 'color': 'default'}}]

# %%
from typing import List

from formatters import BaseFormatter, LatexFormatter, Rephraser
from notion_api import NotionAPI
from utils import blocks_to_markdown
from utils import markdown_to_blocks

notion_api = NotionAPI()

blocks1 = notion_api.read_blocks()
markdown = blocks_to_markdown(blocks1)
blocks2 = markdown_to_blocks(markdown)

# %%
markdown
# Out:
# '- **Inequality constraints**: \\( A_{ineq} x \\leq b_{ineq} \\)\n- \\( A_{eq} \\) and \\( A_{ineq} \\) are matrices defining the linear constraints.'

# %%
blocks1
# Out:
# [{'object': 'block',
#   'id': '14abb2c6-d133-80c8-b3d7-e20872e1ede2',
#   'parent': {'type': 'page_id',
#    'page_id': '14abb2c6-d133-8021-9eaf-c85bab745240'},
#   'created_time': '2024-11-26T06:55:00.000Z',
#   'last_edited_time': '2024-11-26T06:55:00.000Z',
#   'created_by': {'object': 'user',
#    'id': '3c876d9c-6506-491d-ae3f-65fa9933efaa'},
#   'last_edited_by': {'object': 'user',
#    'id': '3c876d9c-6506-491d-ae3f-65fa9933efaa'},
#   'has_children': False,
#   'archived': False,
#   'in_trash': False,
#   'type': 'bulleted_list_item',
#   'bulleted_list_item': {'rich_text': [{'type': 'text',
#      'text': {'content': 'Inequality constraints', 'link': None},
#      'annotations': {'bold': True,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': 'Inequality constraints',
#      'href': None},
#     {'type': 'text',
#      'text': {'content': ': \\( A_{ineq} x \\leq b_{ineq} \\)', 'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': ': \\( A_{ineq} x \\leq b_{ineq} \\)',
#      'href': None}],
#    'color': 'default'}},
#  {'object': 'block',
#   'id': '14abb2c6-d133-805f-80d2-d7e7309138ee',
#   'parent': {'type': 'page_id',
#    'page_id': '14abb2c6-d133-8021-9eaf-c85bab745240'},
#   'created_time': '2024-11-26T06:55:00.000Z',
#   'last_edited_time': '2024-11-26T06:55:00.000Z',
#   'created_by': {'object': 'user',
#    'id': '3c876d9c-6506-491d-ae3f-65fa9933efaa'},
#   'last_edited_by': {'object': 'user',
#    'id': '3c876d9c-6506-491d-ae3f-65fa9933efaa'},
#   'has_children': False,
#   'archived': False,
#   'in_trash': False,
#   'type': 'bulleted_list_item',
#   'bulleted_list_item': {'rich_text': [{'type': 'text',
#      'text': {'content': '\\( A_{eq} \\) and \\( A_{ineq} \\) are matrices defining the linear constraints.',
#       'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': '\\( A_{eq} \\) and \\( A_{ineq} \\) are matrices defining the linear constraints.',
#      'href': None}],
#    'color': 'default'}},
#  {'object': 'block',
#   'id': '14abb2c6-d133-8070-8053-d17bfd827a34',
#   'parent': {'type': 'page_id',
#    'page_id': '14abb2c6-d133-8021-9eaf-c85bab745240'},
#   'created_time': '2024-11-26T07:00:00.000Z',
#   'last_edited_time': '2024-11-26T07:00:00.000Z',
#   'created_by': {'object': 'user',
#    'id': '3c876d9c-6506-491d-ae3f-65fa9933efaa'},
#   'last_edited_by': {'object': 'user',
#    'id': '3c876d9c-6506-491d-ae3f-65fa9933efaa'},
#   'has_children': False,
#   'archived': False,
#   'in_trash': False,
#   'type': 'paragraph',
#   'paragraph': {'rich_text': [], 'color': 'default'}}]

# %%
[
    {
        "object": "block",
        "id": "14abb2c6-d133-80c8-b3d7-e20872e1ede2",
        "parent": {"type": "page_id", "page_id": "14abb2c6-d133-8021-9eaf-c85bab745240"},
        "created_time": "2024-11-26T06:55:00.000Z",
        "last_edited_time": "2024-11-26T06:55:00.000Z",
        "created_by": {"object": "user", "id": "3c876d9c-6506-491d-ae3f-65fa9933efaa"},
        "last_edited_by": {"object": "user", "id": "3c876d9c-6506-491d-ae3f-65fa9933efaa"},
        "has_children": False,
        "archived": False,
        "in_trash": False,
        "type": "bulleted_list_item",
        "bulleted_list_item": {"rich_text": [{"type": "text", "text": {"content": "Inequality constraints", "link": None}, "annotations": {"bold": True, "italic": False, "strikethrough": False, "underline": False, "code": False, "color": "default"}, "plain_text": "Inequality constraints", "href": None}, {"type": "text", "text": {"content": ": \\( A_{ineq} x \\leq b_{ineq} \\)", "link": None}, "annotations": {"bold": False, "italic": False, "strikethrough": False, "underline": False, "code": False, "color": "default"}, "plain_text": ": \\( A_{ineq} x \\leq b_{ineq} \\)", "href": None}], "color": "default"},
    },
    {"object": "block", "id": "14abb2c6-d133-805f-80d2-d7e7309138ee", "parent": {"type": "page_id", "page_id": "14abb2c6-d133-8021-9eaf-c85bab745240"}, "created_time": "2024-11-26T06:55:00.000Z", "last_edited_time": "2024-11-26T06:55:00.000Z", "created_by": {"object": "user", "id": "3c876d9c-6506-491d-ae3f-65fa9933efaa"}, "last_edited_by": {"object": "user", "id": "3c876d9c-6506-491d-ae3f-65fa9933efaa"}, "has_children": False, "archived": False, "in_trash": False, "type": "bulleted_list_item", "bulleted_list_item": {"rich_text": [{"type": "text", "text": {"content": "\\( A_{eq} \\) and \\( A_{ineq} \\) are matrices defining the linear constraints.", "link": None}, "annotations": {"bold": False, "italic": False, "strikethrough": False, "underline": False, "code": False, "color": "default"}, "plain_text": "\\( A_{eq} \\) and \\( A_{ineq} \\) are matrices defining the linear constraints.", "href": None}], "color": "default"}},
    {"object": "block", "id": "14abb2c6-d133-8070-8053-d17bfd827a34", "parent": {"type": "page_id", "page_id": "14abb2c6-d133-8021-9eaf-c85bab745240"}, "created_time": "2024-11-26T07:00:00.000Z", "last_edited_time": "2024-11-26T07:00:00.000Z", "created_by": {"object": "user", "id": "3c876d9c-6506-491d-ae3f-65fa9933efaa"}, "last_edited_by": {"object": "user", "id": "3c876d9c-6506-491d-ae3f-65fa9933efaa"}, "has_children": False, "archived": False, "in_trash": False, "type": "paragraph", "paragraph": {"rich_text": [], "color": "default"}},
]

# %%
[
    {
        "type": "bulleted_list_item",
        "bulleted_list_item": {
            "rich_text": [
                {"type": "text", "text": {"content": "Inequality constraints", "link": None}, "plain_text": "Inequality constraints", "annotations": {"bold": True, "italic": False, "strikethrough": False, "underline": False, "code": False, "color": "default"}, "href": None},
                {"type": "text", "text": {"content": ": ", "link": None}, "plain_text": ": ", "annotations": {"bold": False, "italic": False, "strikethrough": False, "underline": False, "code": False, "color": "default"}, "href": None},
                {"type": "equation", "equation": {"expression": "A_{ineq} x \\leq b_{ineq}"}, "plain_text": "  A_{ineq} x \\leq b_{ineq}  ", "annotations": {"bold": False, "italic": False, "strikethrough": False, "underline": False, "code": False, "color": "default"}, "href": None},
                {"type": "equation", "equation": {"expression": "A_{ineq} x \\leq b_{ineq}"}, "plain_text": "  A_{ineq} x \\leq b_{ineq}  ", "annotations": {"bold": False, "italic": False, "strikethrough": False, "underline": False, "code": False, "color": "default"}, "href": None},
                {"type": "text", "text": {"content": " A_{ineq} x \\leq b_{ineq} ", "link": None}, "plain_text": " A_{ineq} x \\leq b_{ineq} ", "annotations": {"bold": False, "italic": False, "strikethrough": False, "underline": False, "code": False, "color": "default"}, "href": None},
            ],
            "color": "default",
        },
    },
    {
        "type": "bulleted_list_item",
        "bulleted_list_item": {
            "rich_text": [
                {"type": "equation", "equation": {"expression": "A_{eq}"}, "plain_text": "  A_{eq}  ", "annotations": {"bold": False, "italic": False, "strikethrough": False, "underline": False, "code": False, "color": "default"}, "href": None},
                {"type": "equation", "equation": {"expression": "A_{eq}"}, "plain_text": "  A_{eq}  ", "annotations": {"bold": False, "italic": False, "strikethrough": False, "underline": False, "code": False, "color": "default"}, "href": None},
                {"type": "text", "text": {"content": " A_{eq} ", "link": None}, "plain_text": " A_{eq} ", "annotations": {"bold": False, "italic": False, "strikethrough": False, "underline": False, "code": False, "color": "default"}, "href": None},
                {"type": "text", "text": {"content": " and ", "link": None}, "plain_text": " and ", "annotations": {"bold": False, "italic": False, "strikethrough": False, "underline": False, "code": False, "color": "default"}, "href": None},
                {"type": "equation", "equation": {"expression": "A_{ineq}"}, "plain_text": "  A_{ineq}  ", "annotations": {"bold": False, "italic": False, "strikethrough": False, "underline": False, "code": False, "color": "default"}, "href": None},
                {"type": "equation", "equation": {"expression": "A_{ineq}"}, "plain_text": "  A_{ineq}  ", "annotations": {"bold": False, "italic": False, "strikethrough": False, "underline": False, "code": False, "color": "default"}, "href": None},
                {"type": "text", "text": {"content": " A_{ineq} ", "link": None}, "plain_text": " A_{ineq} ", "annotations": {"bold": False, "italic": False, "strikethrough": False, "underline": False, "code": False, "color": "default"}, "href": None},
                {"type": "text", "text": {"content": " are matrices defining the linear constraints.", "link": None}, "plain_text": " are matrices defining the linear constraints.", "annotations": {"bold": False, "italic": False, "strikethrough": False, "underline": False, "code": False, "color": "default"}, "href": None},
            ],
            "color": "default",
        },
    },
]

# %%
blocks2
# Out:
# [{'type': 'bulleted_list_item',
#   'bulleted_list_item': {'rich_text': [{'type': 'text',
#      'text': {'content': 'Inequality constraints', 'link': None},
#      'plain_text': 'Inequality constraints',
#      'annotations': {'bold': True,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'href': None},
#     {'type': 'text',
#      'text': {'content': ': ', 'link': None},
#      'plain_text': ': ',
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'href': None},
#     {'type': 'equation',
#      'equation': {'expression': 'A_{ineq} x \\leq b_{ineq}'},
#      'plain_text': '  A_{ineq} x \\leq b_{ineq}  ',
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'href': None},
#     {'type': 'equation',
#      'equation': {'expression': 'A_{ineq} x \\leq b_{ineq}'},
#      'plain_text': '  A_{ineq} x \\leq b_{ineq}  ',
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'href': None},
#     {'type': 'text',
#      'text': {'content': ' A_{ineq} x \\leq b_{ineq} ', 'link': None},
#      'plain_text': ' A_{ineq} x \\leq b_{ineq} ',
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'href': None}],
#    'color': 'default'}},
#  {'type': 'bulleted_list_item',
#   'bulleted_list_item': {'rich_text': [{'type': 'equation',
#      'equation': {'expression': 'A_{eq}'},
#      'plain_text': '  A_{eq}  ',
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'href': None},
#     {'type': 'equation',
#      'equation': {'expression': 'A_{eq}'},
#      'plain_text': '  A_{eq}  ',
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'href': None},
#     {'type': 'text',
#      'text': {'content': ' A_{eq} ', 'link': None},
#      'plain_text': ' A_{eq} ',
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'href': None},
#     {'type': 'text',
#      'text': {'content': ' and ', 'link': None},
#      'plain_text': ' and ',
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'href': None},
#     {'type': 'equation',
#      'equation': {'expression': 'A_{ineq}'},
#      'plain_text': '  A_{ineq}  ',
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'href': None},
#     {'type': 'equation',
#      'equation': {'expression': 'A_{ineq}'},
#      'plain_text': '  A_{ineq}  ',
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'href': None},
#     {'type': 'text',
#      'text': {'content': ' A_{ineq} ', 'link': None},
#      'plain_text': ' A_{ineq} ',
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'href': None},
#     {'type': 'text',
#      'text': {'content': ' are matrices defining the linear constraints.',
#       'link': None},
#      'plain_text': ' are matrices defining the linear constraints.',
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'href': None}],
#    'color': 'default'}}]
